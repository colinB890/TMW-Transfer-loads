# %% [markdown]
# The goal of this project is to target essential features in each load in order to more accurately pair them with receiving loads.
# To get the exact truck which each transfer load went to is nearly impossible without using brute force, so they must be based on the key
# features such as:
#      1. Province.
#      2. Weight.
#      3. Volume.
#      4. Market.
#
# Even a hand count by a human operator would result in too many errors, and not be able to pair each load with its recipient--therefore,
# the best that can be done is to save the expense of human users of going through potentially thousands of loads, when their time could be
# utilized elsewhere.

# %%
import openpyxl
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import gspread as gs
import ezodf
import openpyxl
from pandas_ods_reader import read_ods
from collections import Counter
import ezodf
import datetime as dt
import xlsxwriter
import calendar

# %%
# filename = pd.ExcelFile("January 2023 Dispatch Sheets.ods")
filename = "TMW_DATA"

# %%
df = pd.read_excel(filename+".xlsX")




###########FILTER OUT IRRELEVANT COLUMNS#########

#df = df.drop(['Unit','Trl1','Drv','Last Inv','Pay Check','Remarks','Unnamed: 22','Unnamed: 23','Carrier','Service','BOL','Product Name',
 #             'Loading Point','Destination'],axis=1)

# %%
##########DATA CLEANING/STRUCTURING##############

df['Started'] = pd.to_datetime(df['Started']) # convert started column to date time series
df['Completed'] = pd.to_datetime(df['Completed']) # convert started column to date time series

###For consideration for a future GUI, these ranges could be filtered.
df = df[df['Started'].dt.year & df['Completed'].dt.year > 2022] #date cleaning. 
df = df[df['Started'].dt.month & df['Completed'].dt.month > 3] #date cleaning

df['Started'] = df['Started'].dt.month #Only get the months now.
df['Completed'] = df['Completed'].dt.month #Only get the months now.


d = dict(enumerate(calendar.month_abbr))

df['Started'] = df['Started'].map(d)
df['Completed'] = df['Completed'].map(d)


#######################Here, weight and volume is rounded to the nearest 1000th, since not all drivers accurately enter data on tablet#####

df.Weight = df["Weight"].round(decimals=-3)
df.Volume = df["Volume"].round(decimals=-3)

df['Shared Date'] = " "

# %%
df
# Out:
#       Unnamed: 0    TMW# Status Started Completed      Load     Dest.  \
# 4544        4544  132684    CMP     Apr       Apr    TIGMIT  TIGNOR01
# 4545        4545  132680    CMP     Apr       Apr    TIGMIT    TIGSPI
# 4548        4548  132687    CMP     Apr       Apr    TIGMIT  TIGNOR01
# 4549        4549  132688    CMP     Apr       Apr    TIGMIT  CUSTPICK
# 4550        4550  132681    CMP     Apr       Apr    TIGMIT  CUSTPICK
# ...          ...     ...    ...     ...       ...       ...       ...
# 8442        8442  137214    CMP     Jun       Jun  TIGPRI05  GOVPRI03
# 8443        8443  137177    CMP     Jun       Jun  TIGVAN01  BABBUR02
# 8444        8444  137195    CMP     Jun       Jun    TIGMIT  PARFOX11
# 8445        8445  137268    CAN     Jun       Jun    TIGMIT    DAWFOR
# 8446        8446  135896    CAN     Jun       Jun  TIGIRR01    ROCCAL
#
#         Prod.   Volume   Weight Market Shared Date
# 4544  1360X00  30000.0  40000.0   DUST
# 4545  1360X00  27000.0  37000.0   DUST
# 4548  1360X00  29000.0  40000.0   DUST
# 4549  1200X11  24000.0  30000.0    OIL
# 4550  1360X17  28000.0  38000.0    OIL
# ...       ...      ...      ...    ...         ...
# 8442  1360X00  29000.0  39000.0   DUST
# 8443  1360X00  30000.0  41000.0   DUST
# 8444  1200X11  28000.0  34000.0    OIL
# 8445  1360X00      0.0      0.0   DUST
# 8446  1340X03      0.0      0.0  DEICE
#
# [3813 rows x 12 columns]

# %%
######EACH PROVINCE HAS THEIR OWN RESPECTIVE LOAD AND DESTINATION DATAFRAMES###########

ttbc_load = df[df['Load'] == 'TTBC']
ttbc_dest = df[df['Dest.'] == 'TTBC']

ttsk_load = df[df['Load'] == 'TTSK']
ttsk_dest = df[df['Dest.'] == 'TTSK']


ttab_load = df[df['Load'] == 'TTAB']
ttab_dest = df[df['Dest.'] == 'TTAB']

#df = df.rename(columns={'oldName1': 'newName1', 'oldName2': 'newName2'})

########CREATE A SHARED DATE COLUMN FOR START/COMPLETE##########

ttbc_load.loc[:,'Shared Date'] = ttbc_load['Completed']
ttbc_dest.loc[:,'Shared Date'] = ttbc_dest['Started'] 

ttab_load.loc[:,'Shared Date'] = ttab_load['Completed']
ttab_dest.loc[:,'Shared Date'] = ttab_dest['Started'] 

ttsk_load.loc[:,'Shared Date'] = ttsk_load['Completed']
ttsk_dest.loc[:,'Shared Date'] = ttsk_dest['Started']
# Out:
# /var/folders/79/y1kk4mzj387ckxj5f0f4hsjw0000gn/T/ipykernel_6542/4056206000.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ttbc_load.loc[:,'Shared Date'] = ttbc_load['Completed']
# /var/folders/79/y1kk4mzj387ckxj5f0f4hsjw0000gn/T/ipykernel_6542/4056206000.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ttbc_dest.loc[:,'Shared Date'] = ttbc_dest['Started']
# /var/folders/79/y1kk4mzj387ckxj5f0f4hsjw0000gn/T/ipykernel_6542/4056206000.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ttab_load.loc[:,'Shared Date'] = ttab_load['Completed']
# /var/folders/79/y1kk4mzj387ckxj5f0f4hsjw0000gn/T/ipykernel_6542/4056206000.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ttab_dest.loc[:,'Shared Date'] = ttab_dest['Started']
# /var/folders/79/y1kk4mzj387ckxj5f0f4hsjw0000gn/T/ipykernel_6542/4056206000.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ttsk_load.loc[:,'Shared Date'] = ttsk_load['Completed']
# /var/folders/79/y1kk4mzj387ckxj5f0f4hsjw0000gn/T/ipykernel_6542/4056206000.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ttsk_dest.loc[:,'Shared Date'] = ttsk_dest['Started']

# %% [markdown]
# Now that a shared date column has been created, the loads are more unique and can be split up accordingly.

# %%
key_cols = ['Prod.', 'Weight', 'Volume','Market','Shared Date'] #Key columns incorporated into pairing process
#ab_merge = ttab_load.merge(ttab_load.loc[:, ttab_dest.columns.isin(key_cols)])

ab_merge = pd.merge(ttab_load, ttab_dest, on = key_cols)
ab_merge = ab_merge.rename(columns={'TMW#_x': 'LOAD TMW#'})
ab_merge = ab_merge.rename(columns={'TMW#_y': 'DEST TMW#'})

bc_merge = pd.merge(ttbc_load, ttbc_dest, on = key_cols)
bc_merge = bc_merge.rename(columns={'TMW#_x': 'LOAD TMW#'})
bc_merge = bc_merge.rename(columns={'TMW#_y': 'DEST TMW#'})

sk_merge = pd.merge(ttsk_load, ttsk_dest, on = key_cols)
sk_merge = sk_merge.rename(columns={'TMW#_x': 'LOAD TMW#'})
sk_merge = sk_merge.rename(columns={'TMW#_y': 'DEST TMW#'})

ab_unused = pd.merge(ttab_load, ttab_dest, how='outer', on=key_cols, indicator=True)
sk_unused = pd.merge(ttsk_load, ttsk_dest, how='outer', on=key_cols, indicator=True)
bc_unused = pd.merge(ttbc_load, ttbc_dest, how='outer', on=key_cols, indicator=True)

ab_unused = ab_unused.drop(['Dest._x','Dest._y','Status_x','Status_y','Market','Prod.','Shared Date'],axis=1)
ab_unused = ab_unused.rename(columns={'_merge': 'UNIQUE'})

sk_unused = sk_unused.drop(['Dest._x','Dest._y','Status_x','Status_y','Market','Prod.','Shared Date'],axis=1)
sk_unused = sk_unused.rename(columns={'_merge': 'UNIQUE'})

bc_unused = bc_unused.drop(['Dest._x','Dest._y','Status_x','Status_y','Market','Prod.','Shared Date'],axis=1)
bc_unused = bc_unused.rename(columns={'_merge': 'UNIQUE'})

# %% [markdown]
# Take a look at the dimensions of each dataframe. We can see some are uneven in the tuples provided.

# %%
print(ab_merge.shape,' ',ttab_dest.shape,' ',ttab_load.shape)
print(sk_merge.shape,' ',ttsk_dest.shape,' ',ttsk_load.shape)
print(bc_merge.shape,' ',ttbc_dest.shape,' ',ttbc_load.shape)
print(df.shape)
# Out:
# (57, 19)   (37, 12)   (37, 12)
# (0, 19)   (4, 12)   (33, 12)
# (141, 19)   (44, 12)   (60, 12)
# (3813, 12)

# %%
# create a excel writer object
with pd.ExcelWriter("Merged_transfers"+".xlsx",engine='xlsxwriter') as writer:
   
    # use to_excel function and specify the sheet_name and index
    # to store the dataframe in specified sheet
    bc_merge.to_excel(writer, sheet_name="BC Merge", index=True)
    ab_merge.to_excel(writer, sheet_name="AB Merge", index=True)
    sk_merge.to_excel(writer, sheet_name="SK Merge", index=True)

    ttbc_dest.to_excel(writer, sheet_name="TTBC dest", index=True)
    ttbc_load.to_excel(writer, sheet_name="TTBC load", index=True)

    ttab_dest.to_excel(writer, sheet_name="TTAB dest", index=True)
    ttab_load.to_excel(writer, sheet_name="TTAB load", index=True)

    ttsk_dest.to_excel(writer, sheet_name="TTSK dest", index=True)
    ttsk_load.to_excel(writer, sheet_name="TTSK load", index=True)

    bc_unused.to_excel(writer, sheet_name="BC Unmerged", index=True)
    ab_unused.to_excel(writer, sheet_name="AB Unmerged", index=True)
    sk_unused.to_excel(writer, sheet_name="SK Unmerged", index=True)

# %% [markdown]
# Generated output to file would be:

# %%
bc_merge
# Out:
#      Unnamed: 0_x  LOAD TMW# Status_x Started_x Completed_x Load_x Dest._x  \
# 0            5530     133784      CMP       May         May   TTBC  ACCARM
# 1            5530     133784      CMP       May         May   TTBC  ACCARM
# 2            5530     133784      CMP       May         May   TTBC  ACCARM
# 3            5530     133784      CMP       May         May   TTBC  ACCARM
# 4            5530     133784      CMP       May         May   TTBC  ACCARM
# ..            ...        ...      ...       ...         ...    ...     ...
# 136          8006     136800      CMP       Jun         Jun   TTBC  PREKIT
# 137          8006     136800      CMP       Jun         Jun   TTBC  PREKIT
# 138          8240     136947      CMP       Jun         Jun   TTBC  CONCHE
# 139          8240     136947      CMP       Jun         Jun   TTBC  CONCHE
# 140          8266     136869      CMP       Jun         Jun   TTBC  CONCHE
#
#        Prod.   Volume   Weight Market Shared Date  Unnamed: 0_y  DEST TMW#  \
# 0    1360X00  29000.0  39000.0   DUST         May          5517     133714
# 1    1360X00  29000.0  39000.0   DUST         May          5703     133925
# 2    1360X00  29000.0  39000.0   DUST         May          5716     133961
# 3    1360X00  29000.0  39000.0   DUST         May          5770     134019
# 4    1360X00  29000.0  39000.0   DUST         May          5981     134242
# ..       ...      ...      ...    ...         ...           ...        ...
# 136  1360X00  30000.0  40000.0   DUST         Jun          7634     135953
# 137  1360X00  30000.0  40000.0   DUST         Jun          8044     136325
# 138  1360X00  26000.0  35000.0   DUST         Jun          7589     136019
# 139  1360X00  26000.0  35000.0   DUST         Jun          7698     136166
# 140  1360X00  27000.0  37000.0   DUST         Jun          8227     136879
#
#     Status_y Started_y Completed_y    Load_y Dest._y
# 0        CMP       May         May  TIGKAM02    TTBC
# 1        CMP       May         May  TIGKAM02    TTBC
# 2        CMP       May         May    TIGKAM    TTBC
# 3        CMP       May         May    TIGKAM    TTBC
# 4        CMP       May         May    TIGKAM    TTBC
# ..       ...       ...         ...       ...     ...
# 136      CMP       Jun         Jun    TIGKAM    TTBC
# 137      CMP       Jun         Jun    TIGDAW    TTBC
# 138      CMP       Jun         Jun    TIGMIT    TTBC
# 139      CMP       Jun         Jun    TIGSPI    TTBC
# 140      CMP       Jun         Jun    TIGMIT    TTBC
#
# [141 rows x 19 columns]

# %%
ab_merge
# Out:
#     Unnamed: 0_x  LOAD TMW# Status_x Started_x Completed_x Load_x   Dest._x  \
# 0           5789     134041      CMP       May         May   TTAB    HILHIG
# 1           6011     134288      CMP       May         May   TTAB    MACFOR
# 2           6011     134288      CMP       May         May   TTAB    MACFOR
# 3           6566     134738      CMP       May         May   TTAB    MCGSAS
# 4           6566     134738      CMP       May         May   TTAB    MCGSAS
# 5           6567     134739      CMP       May         May   TTAB    MCGSAS
# 6           6567     134739      CMP       May         May   TTAB    MCGSAS
# 7           6176     134497      CMP       May         May   TTAB    MACZAM
# 8           6176     134497      CMP       May         May   TTAB    MACZAM
# 9           6176     134497      CMP       May         May   TTAB    MACZAM
# 10          6176     134497      CMP       May         May   TTAB    MACZAM
# 11          6288     134514      CMP       May         May   TTAB    MACZAM
# 12          6288     134514      CMP       May         May   TTAB    MACZAM
# 13          6288     134514      CMP       May         May   TTAB    MACZAM
# 14          6288     134514      CMP       May         May   TTAB    MACZAM
# 15          7427     135772      CMP       May         May   TTAB    LEDNIS
# 16          7427     135772      CMP       May         May   TTAB    LEDNIS
# 17          7427     135772      CMP       May         May   TTAB    LEDNIS
# 18          7427     135772      CMP       May         May   TTAB    LEDNIS
# 19          6203     134496      CMP       May         May   TTAB    MACZAM
# 20          6203     134496      CMP       May         May   TTAB    MACZAM
# 21          6203     134496      CMP       May         May   TTAB    MACZAM
# 22          6203     134496      CMP       May         May   TTAB    MACZAM
# 23          6353     134567      CMP       May         May   TTAB    MACZAM
# 24          6353     134567      CMP       May         May   TTAB    MACZAM
# 25          6353     134567      CMP       May         May   TTAB    MACZAM
# 26          6353     134567      CMP       May         May   TTAB    MACZAM
# 27          7405     135656      CMP       May         May   TTAB    LEDNIS
# 28          7405     135656      CMP       May         May   TTAB    LEDNIS
# 29          7405     135656      CMP       May         May   TTAB    LEDNIS
# 30          7405     135656      CMP       May         May   TTAB    LEDNIS
# 31          6233     134498      CMP       May         May   TTAB    MACZAM
# 32          6327     134565      CMP       May         May   TTAB    MACZAM
# 33          6327     134565      CMP       May         May   TTAB    MACZAM
# 34          6338     134566      CMP       May         May   TTAB    MACZAM
# 35          6338     134566      CMP       May         May   TTAB    MACZAM
# 36          6338     134566      CMP       May         May   TTAB    MACZAM
# 37          6503     134780      CMP       May         May   TTAB  SUNFOR10
# 38          6503     134780      CMP       May         May   TTAB  SUNFOR10
# 39          6503     134780      CMP       May         May   TTAB  SUNFOR10
# 40          6438     134653      CMP       May         May   TTAB    BIRBAY
# 41          7139     135451      CAN       May         May   TTAB    CONCHE
# 42          6549     133639      CMP       May         May   TTAB  FORFOR05
# 43          6603     134822      CMP       May         May   TTAB    LAPRED
# 44          7115     135458      CAN       May         May   TTAB    CONCHE
# 45          7115     135458      CAN       May         May   TTAB    CONCHE
# 46          7596     136059      CMP       Jun         Jun   TTAB    LEDNIS
# 47          7860     136356      CMP       Jun         Jun   TTAB    COUMAN
# 48          7860     136356      CMP       Jun         Jun   TTAB    COUMAN
# 49          8210     136894      CMP       Jun         Jun   TTAB  MUNVAL01
# 50          8210     136894      CMP       Jun         Jun   TTAB  MUNVAL01
# 51          8400     137185      CMP       Jun         Jun   TTAB    ARCVAL
# 52          8400     137185      CMP       Jun         Jun   TTAB    ARCVAL
# 53          8040     136558      CMP       Jun         Jun   TTAB    LEDNIS
# 54          8040     136558      CMP       Jun         Jun   TTAB    LEDNIS
# 55          8177     136697      CMP       Jun         Jun   TTAB    LEDNIS
# 56          8401     137186      CMP       Jun         Jun   TTAB    ARCVAL
#
#       Prod.   Volume   Weight Market Shared Date  Unnamed: 0_y  DEST TMW#  \
# 0   1360X00   8000.0  11000.0   DUST         May          5792     134018
# 1   1360X00  28000.0  38000.0   DUST         May          5961     134218
# 2   1360X00  28000.0  38000.0   DUST         May          7142     135310
# 3   1360X00  28000.0  38000.0   DUST         May          5961     134218
# 4   1360X00  28000.0  38000.0   DUST         May          7142     135310
# 5   1360X00  28000.0  38000.0   DUST         May          5961     134218
# 6   1360X00  28000.0  38000.0   DUST         May          7142     135310
# 7   1360X00  26000.0  36000.0   DUST         May          6043     134365
# 8   1360X00  26000.0  36000.0   DUST         May          6222     134500
# 9   1360X00  26000.0  36000.0   DUST         May          7318     135585
# 10  1360X00  26000.0  36000.0   DUST         May          7467     135781
# 11  1360X00  26000.0  36000.0   DUST         May          6043     134365
# 12  1360X00  26000.0  36000.0   DUST         May          6222     134500
# 13  1360X00  26000.0  36000.0   DUST         May          7318     135585
# 14  1360X00  26000.0  36000.0   DUST         May          7467     135781
# 15  1360X00  26000.0  36000.0   DUST         May          6043     134365
# 16  1360X00  26000.0  36000.0   DUST         May          6222     134500
# 17  1360X00  26000.0  36000.0   DUST         May          7318     135585
# 18  1360X00  26000.0  36000.0   DUST         May          7467     135781
# 19  1360X00  26000.0  35000.0   DUST         May          6050     134364
# 20  1360X00  26000.0  35000.0   DUST         May          6289     134578
# 21  1360X00  26000.0  35000.0   DUST         May          7162     135492
# 22  1360X00  26000.0  35000.0   DUST         May          7266     135606
# 23  1360X00  26000.0  35000.0   DUST         May          6050     134364
# 24  1360X00  26000.0  35000.0   DUST         May          6289     134578
# 25  1360X00  26000.0  35000.0   DUST         May          7162     135492
# 26  1360X00  26000.0  35000.0   DUST         May          7266     135606
# 27  1360X00  26000.0  35000.0   DUST         May          6050     134364
# 28  1360X00  26000.0  35000.0   DUST         May          6289     134578
# 29  1360X00  26000.0  35000.0   DUST         May          7162     135492
# 30  1360X00  26000.0  35000.0   DUST         May          7266     135606
# 31  1360X00  25000.0  35000.0   DUST         May          6044     134366
# 32  1360X00  27000.0  37000.0   DUST         May          6177     134516
# 33  1360X00  27000.0  37000.0   DUST         May          7267     135710
# 34  1360X00  27000.0  36000.0   DUST         May          6290     134579
# 35  1360X00  27000.0  36000.0   DUST         May          6485     134806
# 36  1360X00  27000.0  36000.0   DUST         May          7311     135604
# 37  1360X00  27000.0  36000.0   DUST         May          6290     134579
# 38  1360X00  27000.0  36000.0   DUST         May          6485     134806
# 39  1360X00  27000.0  36000.0   DUST         May          7311     135604
# 40  1360X00  29000.0  40000.0   DUST         May          6405     134655
# 41  1360X00  29000.0  40000.0   DUST         May          6405     134655
# 42  1360X00  25000.0  34000.0   DUST         May          6486     134743
# 43  1360X00  21000.0  29000.0   DUST         May          6568     134874
# 44  1360X00      0.0      0.0   DUST         May          6287     134580
# 45  1360X00      0.0      0.0   DUST         May          7163     135486
# 46  1360X00  27000.0  37000.0   DUST         Jun          7637     136015
# 47  1360X00  28000.0  38000.0   DUST         Jun          7855     136298
# 48  1360X00  28000.0  38000.0   DUST         Jun          8203     136749
# 49  1360X00  28000.0  38000.0   DUST         Jun          7855     136298
# 50  1360X00  28000.0  38000.0   DUST         Jun          8203     136749
# 51  1360X00  28000.0  38000.0   DUST         Jun          7855     136298
# 52  1360X00  28000.0  38000.0   DUST         Jun          8203     136749
# 53  1360X00  25000.0  34000.0   DUST         Jun          7975     136388
# 54  1360X00  25000.0  34000.0   DUST         Jun          8151     136748
# 55  1360X00  24000.0  33000.0   DUST         Jun          8152     136712
# 56  1360X00  28000.0  39000.0   DUST         Jun          8343     137072
#
#    Status_y Started_y Completed_y    Load_y Dest._y
# 0       CMP       May         May    TIGMIT    TTAB
# 1       CMP       May         May    TIGMIT    TTAB
# 2       CMP       May         May    TIGMIT    TTAB
# 3       CMP       May         May    TIGMIT    TTAB
# 4       CMP       May         May    TIGMIT    TTAB
# 5       CMP       May         May    TIGMIT    TTAB
# 6       CMP       May         May    TIGMIT    TTAB
# 7       CMP       May         May    TIGMIT    TTAB
# 8       CMP       May         May    TIGMIT    TTAB
# 9       CMP       May         May    TIGMIT    TTAB
# 10      CMP       May         Jun    TIGMIT    TTAB
# 11      CMP       May         May    TIGMIT    TTAB
# 12      CMP       May         May    TIGMIT    TTAB
# 13      CMP       May         May    TIGMIT    TTAB
# 14      CMP       May         Jun    TIGMIT    TTAB
# 15      CMP       May         May    TIGMIT    TTAB
# 16      CMP       May         May    TIGMIT    TTAB
# 17      CMP       May         May    TIGMIT    TTAB
# 18      CMP       May         Jun    TIGMIT    TTAB
# 19      CMP       May         May    TIGMIT    TTAB
# 20      CMP       May         May    TIGMIT    TTAB
# 21      CMP       May         May    TIGSEX    TTAB
# 22      CMP       May         May    TIGMIT    TTAB
# 23      CMP       May         May    TIGMIT    TTAB
# 24      CMP       May         May    TIGMIT    TTAB
# 25      CMP       May         May    TIGSEX    TTAB
# 26      CMP       May         May    TIGMIT    TTAB
# 27      CMP       May         May    TIGMIT    TTAB
# 28      CMP       May         May    TIGMIT    TTAB
# 29      CMP       May         May    TIGSEX    TTAB
# 30      CMP       May         May    TIGMIT    TTAB
# 31      CMP       May         May    TIGMIT    TTAB
# 32      CMP       May         May    TIGMIT    TTAB
# 33      CMP       May         May    TIGMIT    TTAB
# 34      CMP       May         May    TIGMIT    TTAB
# 35      CMP       May         May    TIGMIT    TTAB
# 36      CMP       May         May    TIGMIT    TTAB
# 37      CMP       May         May    TIGMIT    TTAB
# 38      CMP       May         May    TIGMIT    TTAB
# 39      CMP       May         May    TIGMIT    TTAB
# 40      CMP       May         May    TIGSPI    TTAB
# 41      CMP       May         May    TIGSPI    TTAB
# 42      CMP       May         May    TIGMIT    TTAB
# 43      CMP       May         May    TIGMIT    TTAB
# 44      CAN       May         May    TIGMIT    TTAB
# 45      CAN       May         May  TIGGRA01    TTAB
# 46      CMP       Jun         Jun    TIGNIS    TTAB
# 47      CMP       Jun         Jun    TIGMIT    TTAB
# 48      CMP       Jun         Jun    TIGMIT    TTAB
# 49      CMP       Jun         Jun    TIGMIT    TTAB
# 50      CMP       Jun         Jun    TIGMIT    TTAB
# 51      CMP       Jun         Jun    TIGMIT    TTAB
# 52      CMP       Jun         Jun    TIGMIT    TTAB
# 53      CMP       Jun         Jun    TIGMIT    TTAB
# 54      CMP       Jun         Jun    TIGMIT    TTAB
# 55      CMP       Jun         Jun    TIGMIT    TTAB
# 56      CMP       Jun         Jun    TIGMIT    TTAB

# %%
sk_merge
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0_x, LOAD TMW#, Status_x, Started_x, Completed_x, Load_x, Dest._x, Prod., Volume, Weight, Market, Shared Date, Unnamed: 0_y, DEST TMW#, Status_y, Started_y, Completed_y, Load_y, Dest._y]
# Index: []

# %%
bc_unused
# Out:
#      Unnamed: 0_x    TMW#_x Started_x Completed_x Load_x   Volume   Weight  \
# 0          5268.0  133486.0       Apr         Apr   TTBC  22000.0  31000.0
# 1          5272.0  133487.0       Apr         Apr   TTBC   6000.0   9000.0
# 2          5456.0  133684.0       May         May   TTBC   7000.0   9000.0
# 3          5481.0  133664.0       May         May   TTBC  22000.0  30000.0
# 4          6705.0  135025.0       May         May   TTBC  22000.0  30000.0
# ..            ...       ...       ...         ...    ...      ...      ...
# 165           NaN       NaN       NaN         NaN    NaN  30000.0  41000.0
# 166           NaN       NaN       NaN         NaN    NaN  25000.0  35000.0
# 167           NaN       NaN       NaN         NaN    NaN  27000.0  36000.0
# 168           NaN       NaN       NaN         NaN    NaN  29000.0  39000.0
# 169           NaN       NaN       NaN         NaN    NaN  24000.0  33000.0
#
#      Unnamed: 0_y    TMW#_y Started_y Completed_y    Load_y      UNIQUE
# 0             NaN       NaN       NaN         NaN       NaN   left_only
# 1             NaN       NaN       NaN         NaN       NaN   left_only
# 2             NaN       NaN       NaN         NaN       NaN   left_only
# 3             NaN       NaN       NaN         NaN       NaN   left_only
# 4             NaN       NaN       NaN         NaN       NaN   left_only
# ..            ...       ...       ...         ...       ...         ...
# 165        5574.0  133791.0       May         May  TIGKAM02  right_only
# 166        7069.0  135412.0       May         May    TIGMIT  right_only
# 167        7604.0  136020.0       Jun         Jun    TIGMIT  right_only
# 168        7753.0  136158.0       Jun         Jun    TIGMIT  right_only
# 169        7755.0  136165.0       Jun         Jun    TIGSPI  right_only
#
# [170 rows x 13 columns]

# %%
ab_unused
# Out:
#     Unnamed: 0_x    TMW#_x Started_x Completed_x Load_x   Volume   Weight  \
# 0         5789.0  134041.0       May         May   TTAB   8000.0  11000.0
# 1         6011.0  134288.0       May         May   TTAB  28000.0  38000.0
# 2         6011.0  134288.0       May         May   TTAB  28000.0  38000.0
# 3         6566.0  134738.0       May         May   TTAB  28000.0  38000.0
# 4         6566.0  134738.0       May         May   TTAB  28000.0  38000.0
# ..           ...       ...       ...         ...    ...      ...      ...
# 71           NaN       NaN       NaN         NaN    NaN  27000.0  36000.0
# 72           NaN       NaN       NaN         NaN    NaN  21000.0  28000.0
# 73           NaN       NaN       NaN         NaN    NaN      0.0      0.0
# 74           NaN       NaN       NaN         NaN    NaN  26000.0  36000.0
# 75           NaN       NaN       NaN         NaN    NaN  26000.0  36000.0
#
#     Unnamed: 0_y    TMW#_y Started_y Completed_y  Load_y      UNIQUE
# 0         5792.0  134018.0       May         May  TIGMIT        both
# 1         5961.0  134218.0       May         May  TIGMIT        both
# 2         7142.0  135310.0       May         May  TIGMIT        both
# 3         5961.0  134218.0       May         May  TIGMIT        both
# 4         7142.0  135310.0       May         May  TIGMIT        both
# ..           ...       ...       ...         ...     ...         ...
# 71        7433.0  135690.0       May         May  TIGMIT  right_only
# 72        8011.0  136442.0       Jun         Jun  TIGMIT  right_only
# 73        8153.0  136703.0       Jun         Jun  TIGMIT  right_only
# 74        8292.0  137035.0       Jun         Jun  TIGMIT  right_only
# 75        8342.0  137044.0       Jun         Jun  TIGMIT  right_only
#
# [76 rows x 13 columns]

# %%
sk_unused
# Out:
#     Unnamed: 0_x    TMW#_x Started_x Completed_x Load_x   Volume   Weight  \
# 0         7010.0  135280.0       May         May   TTSK  18000.0  24000.0
# 1         7015.0  135339.0       May         May   TTSK  11000.0  15000.0
# 2         7026.0  135340.0       May         May   TTSK  29000.0  39000.0
# 3         7444.0  135823.0       May         May   TTSK  27000.0  37000.0
# 4         7829.0  136301.0       Jun         Jun   TTSK  23000.0  31000.0
# 5         7937.0  136302.0       Jun         Jun   TTSK  23000.0  31000.0
# 6         7968.0  136305.0       Jun         Jun   TTSK  23000.0  31000.0
# 7         7972.0  136307.0       Jun         Jun   TTSK  23000.0  31000.0
# 8         8030.0  136310.0       Jun         Jun   TTSK  23000.0  31000.0
# 9         8039.0  136311.0       Jun         Jun   TTSK  23000.0  31000.0
# 10        8258.0  136851.0       Jun         Jun   TTSK  23000.0  31000.0
# 11        8264.0  136852.0       Jun         Jun   TTSK  23000.0  31000.0
# 12        7942.0  136304.0       Jun         Jun   TTSK  29000.0  39000.0
# 13        8100.0  136524.0       Jun         Jun   TTSK  29000.0  39000.0
# 14        8110.0  136525.0       Jun         Jun   TTSK  29000.0  39000.0
# 15        8319.0  137000.0       Jun         Jun   TTSK  29000.0  39000.0
# 16        8003.0  136308.0       Jun         Jun   TTSK  28000.0  30000.0
# 17        8023.0  136309.0       Jun         Jun   TTSK  22000.0  30000.0
# 18        8041.0  136522.0       Jun         Jun   TTSK  22000.0  30000.0
# 19        8048.0  136523.0       Jun         Jun   TTSK  22000.0  30000.0
# 20        8128.0  136526.0       Jun         Jun   TTSK  22000.0  30000.0
# 21        8307.0  136853.0       Jun         Jun   TTSK  22000.0  30000.0
# 22        8129.0  136527.0       Jun         Jun   TTSK  16000.0  22000.0
# 23        8195.0  136531.0       Jun         Jun   TTSK  16000.0  22000.0
# 24        8196.0  136706.0       Jun         Jun   TTSK  16000.0  22000.0
# 25        8134.0  136528.0       Jun         Jun   TTSK  30000.0  41000.0
# 26        8174.0  136529.0       Jun         Jun   TTSK  18000.0  24000.0
# 27        8236.0  136849.0       Jun         Jun   TTSK  18000.0  24000.0
# 28        8175.0  136530.0       Jun         Jun   TTSK  25000.0  34000.0
# 29        8222.0  136847.0       Jun         Jun   TTSK  25000.0  34000.0
# 30        8233.0  136848.0       Jun         Jun   TTSK  20000.0  27000.0
# 31        8237.0  136850.0       Jun         Jun   TTSK  19000.0  26000.0
# 32        8308.0  136854.0       Jun         Jun   TTSK  24000.0  33000.0
# 33           NaN       NaN       NaN         NaN    NaN  30000.0  41000.0
# 34           NaN       NaN       NaN         NaN    NaN  30000.0  41000.0
# 35           NaN       NaN       NaN         NaN    NaN  28000.0  30000.0
# 36           NaN       NaN       NaN         NaN    NaN      0.0      0.0
#
#     Unnamed: 0_y    TMW#_y Started_y Completed_y    Load_y      UNIQUE
# 0            NaN       NaN       NaN         NaN       NaN   left_only
# 1            NaN       NaN       NaN         NaN       NaN   left_only
# 2            NaN       NaN       NaN         NaN       NaN   left_only
# 3            NaN       NaN       NaN         NaN       NaN   left_only
# 4            NaN       NaN       NaN         NaN       NaN   left_only
# 5            NaN       NaN       NaN         NaN       NaN   left_only
# 6            NaN       NaN       NaN         NaN       NaN   left_only
# 7            NaN       NaN       NaN         NaN       NaN   left_only
# 8            NaN       NaN       NaN         NaN       NaN   left_only
# 9            NaN       NaN       NaN         NaN       NaN   left_only
# 10           NaN       NaN       NaN         NaN       NaN   left_only
# 11           NaN       NaN       NaN         NaN       NaN   left_only
# 12           NaN       NaN       NaN         NaN       NaN   left_only
# 13           NaN       NaN       NaN         NaN       NaN   left_only
# 14           NaN       NaN       NaN         NaN       NaN   left_only
# 15           NaN       NaN       NaN         NaN       NaN   left_only
# 16           NaN       NaN       NaN         NaN       NaN   left_only
# 17           NaN       NaN       NaN         NaN       NaN   left_only
# 18           NaN       NaN       NaN         NaN       NaN   left_only
# 19           NaN       NaN       NaN         NaN       NaN   left_only
# 20           NaN       NaN       NaN         NaN       NaN   left_only
# 21           NaN       NaN       NaN         NaN       NaN   left_only
# 22           NaN       NaN       NaN         NaN       NaN   left_only
# 23           NaN       NaN       NaN         NaN       NaN   left_only
# 24           NaN       NaN       NaN         NaN       NaN   left_only
# 25           NaN       NaN       NaN         NaN       NaN   left_only
# 26           NaN       NaN       NaN         NaN       NaN   left_only
# 27           NaN       NaN       NaN         NaN       NaN   left_only
# 28           NaN       NaN       NaN         NaN       NaN   left_only
# 29           NaN       NaN       NaN         NaN       NaN   left_only
# 30           NaN       NaN       NaN         NaN       NaN   left_only
# 31           NaN       NaN       NaN         NaN       NaN   left_only
# 32           NaN       NaN       NaN         NaN       NaN   left_only
# 33        7004.0  134947.0       May         May    TIGMAR  right_only
# 34        7005.0  134950.0       May         May    TIGMAR  right_only
# 35        7965.0  136213.0       Jun         Jun    TIGMAR  right_only
# 36        8095.0  136627.0       Jun         Jun  TIGPRI05  right_only
